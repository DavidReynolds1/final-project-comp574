# %% [markdown]
# # Project Milestone 1 - Getting Data

# %%
# As of right now these are the only two locations that I know will work and are populated fully
# All location must be within the United States - I convert US zipcodes later on
# 03301 = Zip code for Concord, NH
# 03060 = Zip Code for Nashua, NH
import requests, json, pandas as pd

api_key = "8390c20af9c3e9f5dcf4f89d947eba14"
base_url = "http://api.openweathermap.org/data/2.5/forecast?"
zips=["03301", "03867"]

# For loop to split up different zips as I want two separate dataframes. Probably not the best way, but functional.
for zip in zips:
    if zip == "03301":
        complete_url = base_url + "zip=" + zip + "&appid=" + api_key
    else:
        complete_url1 = base_url + "zip=" + zip + "&appid=" + api_key

# %%
# creates json payload for the urls made above
payload = requests.get(complete_url).json()
payload1 = requests.get(complete_url1).json()

# %%
# Creates dataframes from the payload --- normalize = json --> dataframe
df = pd.json_normalize(payload["list"]).drop("main.temp_kf", axis= 1)
df1 = pd.json_normalize(payload1["list"]).drop("main.temp_kf", axis= 1)

# %%
# Sends each dataframe to a csv file for the location
# headers will be column names by default
# Index = false is needed so that the datframe indexes do not become Unnamed: 0
#df.to_csv(r"C:\Users\david\Documents\comp574-active\final-project-comp574\city1.csv", index=False)
#df1.to_csv(r"C:\Users\david\Documents\comp574-active\final-project-comp574\bose.csv",index=False)
df1.columns
# Out:
# Index(['dt', 'weather', 'visibility', 'pop', 'dt_txt', 'main.temp',
#        'main.feels_like', 'main.temp_min', 'main.temp_max', 'main.pressure',
#        'main.sea_level', 'main.grnd_level', 'main.humidity', 'clouds.all',
#        'wind.speed', 'wind.deg', 'wind.gust', 'sys.pod', 'rain.3h'],
#       dtype='object')

# %%
# Read file to make sure everything works  ; - hides output as I do not actually need output
##pd.read_csv(r"C:\Users\david\Documents\comp574-active\final-project-comp574\city1.csv");

# %%
# Read file to make sure that everything works   ; - hides output as I do not actually need output
#;

# %% [markdown]
# # **Project Milestone 2 - Descriptive Data Analysis**

# %% [markdown]
# Describe at least three questions that your analysis is meant to answer, and describe how these questions are answered. (25 pts)

# %%
df1
# Out:
#             dt                                            weather  visibility  \
# 0   1639040400  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 1   1639051200  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 2   1639062000  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 3   1639072800  [{'id': 801, 'main': 'Clouds', 'description': ...       10000
# 4   1639083600  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 5   1639094400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 6   1639105200  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 7   1639116000  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 8   1639126800  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 9   1639137600  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 10  1639148400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 11  1639159200  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 12  1639170000  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 13  1639180800  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 14  1639191600  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 15  1639202400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 16  1639213200  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 17  1639224000  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 18  1639234800  [{'id': 500, 'main': 'Rain', 'description': 'l...        1403
# 19  1639245600  [{'id': 500, 'main': 'Rain', 'description': 'l...        2638
# 20  1639256400  [{'id': 500, 'main': 'Rain', 'description': 'l...       10000
# 21  1639267200  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 22  1639278000  [{'id': 500, 'main': 'Rain', 'description': 'l...       10000
# 23  1639288800  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 24  1639299600  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 25  1639310400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 26  1639321200  [{'id': 801, 'main': 'Clouds', 'description': ...       10000
# 27  1639332000  [{'id': 801, 'main': 'Clouds', 'description': ...       10000
# 28  1639342800  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 29  1639353600  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 30  1639364400  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 31  1639375200  [{'id': 801, 'main': 'Clouds', 'description': ...       10000
# 32  1639386000  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 33  1639396800  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 34  1639407600  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 35  1639418400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 36  1639429200  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 37  1639440000  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 38  1639450800  [{'id': 801, 'main': 'Clouds', 'description': ...       10000
# 39  1639461600  [{'id': 801, 'main': 'Clouds', 'description': ...       10000
#
#      pop               dt_txt  main.temp  main.feels_like  main.temp_min  \
# 0   0.01  2021-12-09 09:00:00     268.38           268.38         268.38
# 1   0.00  2021-12-09 12:00:00     268.63           266.22         268.63
# 2   0.00  2021-12-09 15:00:00     274.19           269.80         274.19
# 3   0.00  2021-12-09 18:00:00     275.22           271.04         275.22
# 4   0.00  2021-12-09 21:00:00     272.92           269.74         272.92
# 5   0.00  2021-12-10 00:00:00     271.67           271.67         271.67
# 6   0.00  2021-12-10 03:00:00     271.06           271.06         271.06
# 7   0.00  2021-12-10 06:00:00     269.88           269.88         269.88
# 8   0.00  2021-12-10 09:00:00     270.79           270.79         270.79
# 9   0.00  2021-12-10 12:00:00     271.61           271.61         271.61
# 10  0.14  2021-12-10 15:00:00     274.02           271.19         274.02
# 11  0.14  2021-12-10 18:00:00     277.46           274.88         277.46
# 12  0.00  2021-12-10 21:00:00     274.08           274.08         274.08
# 13  0.00  2021-12-11 00:00:00     273.28           273.28         273.28
# 14  0.00  2021-12-11 03:00:00     273.01           273.01         273.01
# 15  0.00  2021-12-11 06:00:00     272.91           272.91         272.91
# 16  0.00  2021-12-11 09:00:00     273.21           273.21         273.21
# 17  0.00  2021-12-11 12:00:00     273.84           273.84         273.84
# 18  0.65  2021-12-11 15:00:00     276.61           275.14         276.61
# 19  0.89  2021-12-11 18:00:00     281.62           279.80         281.62
# 20  0.53  2021-12-11 21:00:00     287.56           287.51         287.56
# 21  0.58  2021-12-12 00:00:00     288.66           288.62         288.66
# 22  1.00  2021-12-12 03:00:00     287.09           286.52         287.09
# 23  0.76  2021-12-12 06:00:00     277.13           272.05         277.13
# 24  0.00  2021-12-12 09:00:00     276.77           271.90         276.77
# 25  0.00  2021-12-12 12:00:00     275.37           270.81         275.37
# 26  0.00  2021-12-12 15:00:00     277.10           273.21         277.10
# 27  0.00  2021-12-12 18:00:00     279.14           275.69         279.14
# 28  0.00  2021-12-12 21:00:00     277.00           273.22         277.00
# 29  0.00  2021-12-13 00:00:00     275.05           271.10         275.05
# 30  0.00  2021-12-13 03:00:00     274.08           270.08         274.08
# 31  0.00  2021-12-13 06:00:00     273.89           270.03         273.89
# 32  0.00  2021-12-13 09:00:00     275.04           271.08         275.04
# 33  0.00  2021-12-13 12:00:00     275.82           272.18         275.82
# 34  0.00  2021-12-13 15:00:00     278.88           275.30         278.88
# 35  0.00  2021-12-13 18:00:00     282.66           279.49         282.66
# 36  0.00  2021-12-13 21:00:00     280.89           277.20         280.89
# 37  0.00  2021-12-14 00:00:00     279.15           275.14         279.15
# 38  0.00  2021-12-14 03:00:00     278.08           273.93         278.08
# 39  0.00  2021-12-14 06:00:00     276.18           271.92         276.18
#
#     main.temp_max  main.pressure  main.sea_level  main.grnd_level  \
# 0          269.16           1014            1014             1006
# 1          268.95           1016            1016             1008
# 2          274.19           1019            1019             1010
# 3          275.22           1019            1019             1011
# 4          272.92           1022            1022             1013
# 5          271.67           1024            1024             1015
# 6          271.06           1025            1025             1016
# 7          269.88           1025            1025             1016
# 8          270.79           1024            1024             1015
# 9          271.61           1024            1024             1016
# 10         274.02           1024            1024             1015
# 11         277.46           1021            1021             1013
# 12         274.08           1021            1021             1012
# 13         273.28           1021            1021             1013
# 14         273.01           1021            1021             1013
# 15         272.91           1019            1019             1011
# 16         273.21           1018            1018             1009
# 17         273.84           1015            1015             1006
# 18         276.61           1010            1010             1002
# 19         281.62           1004            1004              996
# 20         287.56           1001            1001              993
# 21         288.66            998             998              990
# 22         287.09            998             998              990
# 23         277.13           1004            1004              996
# 24         276.77           1008            1008             1000
# 25         275.37           1013            1013             1004
# 26         277.10           1016            1016             1008
# 27         279.14           1017            1017             1009
# 28         277.00           1018            1018             1010
# 29         275.05           1021            1021             1012
# 30         274.08           1021            1021             1012
# 31         273.89           1021            1021             1013
# 32         275.04           1020            1020             1012
# 33         275.82           1020            1020             1011
# 34         278.88           1019            1019             1010
# 35         282.66           1014            1014             1006
# 36         280.89           1015            1015             1006
# 37         279.15           1018            1018             1009
# 38         278.08           1020            1020             1012
# 39         276.18           1023            1023             1014
#
#     main.humidity  clouds.all  wind.speed  wind.deg  wind.gust sys.pod  \
# 0              83          82        0.75       321       1.58       n
# 1              87          57        1.51       255       5.89       n
# 2              50           8        4.54       296       6.94       d
# 3              36          14        4.60       303       7.06       d
# 4              44          93        2.61       311       5.95       d
# 5              49          96        1.31       296       2.97       n
# 6              54         100        0.91        24       1.16       n
# 7              62          99        0.90        23       0.96       n
# 8              59          99        0.28       121       0.72       n
# 9              53         100        0.65       107       1.30       n
# 10             64         100        2.47       167       6.35       d
# 11             60         100        2.93       203       6.70       d
# 12             79         100        0.94       193       0.96       d
# 13             87          93        0.85       269       0.83       n
# 14             93          85        1.00       272       0.94       n
# 15             95          92        0.96       252       1.06       n
# 16             95          99        0.40       167       0.49       n
# 17             96          99        1.13       184       1.13       n
# 18             99         100        1.65       167      15.59       d
# 19             99         100        3.04       214      13.31       d
# 20             94         100        7.30       207      18.48       d
# 21             90         100        8.01       209      22.59       n
# 22             76         100        8.70       272      18.70       n
# 23             67         100        7.85       269      20.53       n
# 24             63         100        6.97       279      18.70       n
# 25             63          86        5.38       284      15.38       n
# 26             53          12        4.92       280      12.73       d
# 27             49          22        5.07       268      11.93       d
# 28             61           0        4.66       265      10.84       d
# 29             65           0        4.16       259      12.83       n
# 30             63           0        3.89       243      12.41       n
# 31             68          13        3.64       235      12.26       n
# 32             62         100        4.17       246      14.35       n
# 33             58         100        3.94       238      14.24       n
# 34             49         100        5.22       234      16.16       d
# 35             41          86        6.89       238      18.08       d
# 36             46           0        6.94       268      18.29       d
# 37             57           0        6.47       284      16.76       n
# 38             65          18        6.06       292      14.49       n
# 39             63          11        5.20       288      13.25       n
#
#     rain.3h
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18     0.59
# 19     0.95
# 20     0.31
# 21      NaN
# 22     1.27
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
# 30      NaN
# 31      NaN
# 32      NaN
# 33      NaN
# 34      NaN
# 35      NaN
# 36      NaN
# 37      NaN
# 38      NaN
# 39      NaN

# %%
df["zip"] = zips[0]
df1["zip"] = zips[1]

# %%
df.rename(columns={"dt_txt": "Time of Day"}, inplace=True)
df1.rename(columns={"dt_txt": "Time of Day"}, inplace=True)

# %%
df2 = df.append(df1)

# %%
df2.reset_index(drop="index", inplace=True)
df2
# Out:
#             dt                                            weather  visibility  \
# 0   1639040400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 1   1639051200  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 2   1639062000  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 3   1639072800  [{'id': 802, 'main': 'Clouds', 'description': ...       10000
# 4   1639083600  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# ..         ...                                                ...         ...
# 75  1639418400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 76  1639429200  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 77  1639440000  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 78  1639450800  [{'id': 801, 'main': 'Clouds', 'description': ...       10000
# 79  1639461600  [{'id': 801, 'main': 'Clouds', 'description': ...       10000
#
#     pop          Time of Day  main.temp  main.feels_like  main.temp_min  \
# 0   0.0  2021-12-09 09:00:00     269.07           269.07         269.07
# 1   0.0  2021-12-09 12:00:00     269.14           266.68         269.14
# 2   0.0  2021-12-09 15:00:00     273.95           269.53         273.95
# 3   0.0  2021-12-09 18:00:00     275.21           271.30         275.21
# 4   0.0  2021-12-09 21:00:00     272.88           269.48         272.88
# ..  ...                  ...        ...              ...            ...
# 75  0.0  2021-12-13 18:00:00     282.66           279.49         282.66
# 76  0.0  2021-12-13 21:00:00     280.89           277.20         280.89
# 77  0.0  2021-12-14 00:00:00     279.15           275.14         279.15
# 78  0.0  2021-12-14 03:00:00     278.08           273.93         278.08
# 79  0.0  2021-12-14 06:00:00     276.18           271.92         276.18
#
#     main.temp_max  main.pressure  main.sea_level  main.grnd_level  \
# 0          269.50           1014            1014             1006
# 1          269.28           1016            1016             1009
# 2          273.95           1019            1019             1011
# 3          275.21           1020            1020             1011
# 4          272.88           1022            1022             1014
# ..            ...            ...             ...              ...
# 75         282.66           1014            1014             1006
# 76         280.89           1015            1015             1006
# 77         279.15           1018            1018             1009
# 78         278.08           1020            1020             1012
# 79         276.18           1023            1023             1014
#
#     main.humidity  clouds.all  wind.speed  wind.deg  wind.gust sys.pod  \
# 0              90          86        0.71       253       0.88       n
# 1              92          61        1.58       269       4.31       n
# 2              51           7        4.50       305       7.40       d
# 3              38          38        4.16       304       6.51       d
# 4              46          99        2.83       320       6.01       d
# ..            ...         ...         ...       ...        ...     ...
# 75             41          86        6.89       238      18.08       d
# 76             46           0        6.94       268      18.29       d
# 77             57           0        6.47       284      16.76       n
# 78             65          18        6.06       292      14.49       n
# 79             63          11        5.20       288      13.25       n
#
#     rain.3h    zip
# 0       NaN  03301
# 1       NaN  03301
# 2       NaN  03301
# 3       NaN  03301
# 4       NaN  03301
# ..      ...    ...
# 75      NaN  03867
# 76      NaN  03867
# 77      NaN  03867
# 78      NaN  03867
# 79      NaN  03867
#
# [80 rows x 20 columns]

# %%
from pyzipcode import ZipCodeDatabase
zipdb = ZipCodeDatabase()
df2["city"] = df2["zip"].apply(lambda x : zipdb[x].city)

# %%
df2
# Out:
#             dt                                            weather  visibility  \
# 0   1639040400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 1   1639051200  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 2   1639062000  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 3   1639072800  [{'id': 802, 'main': 'Clouds', 'description': ...       10000
# 4   1639083600  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# ..         ...                                                ...         ...
# 75  1639418400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 76  1639429200  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 77  1639440000  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 78  1639450800  [{'id': 801, 'main': 'Clouds', 'description': ...       10000
# 79  1639461600  [{'id': 801, 'main': 'Clouds', 'description': ...       10000
#
#     pop          Time of Day  main.temp  main.feels_like  main.temp_min  \
# 0   0.0  2021-12-09 09:00:00     269.07           269.07         269.07
# 1   0.0  2021-12-09 12:00:00     269.14           266.68         269.14
# 2   0.0  2021-12-09 15:00:00     273.95           269.53         273.95
# 3   0.0  2021-12-09 18:00:00     275.21           271.30         275.21
# 4   0.0  2021-12-09 21:00:00     272.88           269.48         272.88
# ..  ...                  ...        ...              ...            ...
# 75  0.0  2021-12-13 18:00:00     282.66           279.49         282.66
# 76  0.0  2021-12-13 21:00:00     280.89           277.20         280.89
# 77  0.0  2021-12-14 00:00:00     279.15           275.14         279.15
# 78  0.0  2021-12-14 03:00:00     278.08           273.93         278.08
# 79  0.0  2021-12-14 06:00:00     276.18           271.92         276.18
#
#     main.temp_max  main.pressure  ...  main.grnd_level  main.humidity  \
# 0          269.50           1014  ...             1006             90
# 1          269.28           1016  ...             1009             92
# 2          273.95           1019  ...             1011             51
# 3          275.21           1020  ...             1011             38
# 4          272.88           1022  ...             1014             46
# ..            ...            ...  ...              ...            ...
# 75         282.66           1014  ...             1006             41
# 76         280.89           1015  ...             1006             46
# 77         279.15           1018  ...             1009             57
# 78         278.08           1020  ...             1012             65
# 79         276.18           1023  ...             1014             63
#
#     clouds.all  wind.speed  wind.deg  wind.gust  sys.pod rain.3h    zip  \
# 0           86        0.71       253       0.88        n     NaN  03301
# 1           61        1.58       269       4.31        n     NaN  03301
# 2            7        4.50       305       7.40        d     NaN  03301
# 3           38        4.16       304       6.51        d     NaN  03301
# 4           99        2.83       320       6.01        d     NaN  03301
# ..         ...         ...       ...        ...      ...     ...    ...
# 75          86        6.89       238      18.08        d     NaN  03867
# 76           0        6.94       268      18.29        d     NaN  03867
# 77           0        6.47       284      16.76        n     NaN  03867
# 78          18        6.06       292      14.49        n     NaN  03867
# 79          11        5.20       288      13.25        n     NaN  03867
#
#          city
# 0     Concord
# 1     Concord
# 2     Concord
# 3     Concord
# 4     Concord
# ..        ...
# 75  Rochester
# 76  Rochester
# 77  Rochester
# 78  Rochester
# 79  Rochester
#
# [80 rows x 21 columns]

# %% [markdown]
# ## Determine appropriate measures of central tendency (Mean, Mode, and Median ) and dispersion (E.g. Variance, Standard deviation) for at least three selected variables, including one quantitative variable (column) and one qualitative variable (column). For a quantitative variable, select at least one measure of central tendency and at least one measure of variance ( Sample Standard Deviation or Variance). For the qualitative variable, select one measure of central tendency. (20 pts)
#
# ### **Note: I only have so many variables so I will have to double up on the qualitative variable**

# %% [markdown]
# #### First I converted all of the temperature columns to fahrenheit so that they make sense for the average United States citizen

# %%
df2
# Out:
#             dt                                            weather  visibility  \
# 0   1639040400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 1   1639051200  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 2   1639062000  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 3   1639072800  [{'id': 802, 'main': 'Clouds', 'description': ...       10000
# 4   1639083600  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# ..         ...                                                ...         ...
# 75  1639418400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 76  1639429200  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 77  1639440000  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 78  1639450800  [{'id': 801, 'main': 'Clouds', 'description': ...       10000
# 79  1639461600  [{'id': 801, 'main': 'Clouds', 'description': ...       10000
#
#     pop          Time of Day  main.temp  main.feels_like  main.temp_min  \
# 0   0.0  2021-12-09 09:00:00     269.07           269.07         269.07
# 1   0.0  2021-12-09 12:00:00     269.14           266.68         269.14
# 2   0.0  2021-12-09 15:00:00     273.95           269.53         273.95
# 3   0.0  2021-12-09 18:00:00     275.21           271.30         275.21
# 4   0.0  2021-12-09 21:00:00     272.88           269.48         272.88
# ..  ...                  ...        ...              ...            ...
# 75  0.0  2021-12-13 18:00:00     282.66           279.49         282.66
# 76  0.0  2021-12-13 21:00:00     280.89           277.20         280.89
# 77  0.0  2021-12-14 00:00:00     279.15           275.14         279.15
# 78  0.0  2021-12-14 03:00:00     278.08           273.93         278.08
# 79  0.0  2021-12-14 06:00:00     276.18           271.92         276.18
#
#     main.temp_max  main.pressure  ...  main.grnd_level  main.humidity  \
# 0          269.50           1014  ...             1006             90
# 1          269.28           1016  ...             1009             92
# 2          273.95           1019  ...             1011             51
# 3          275.21           1020  ...             1011             38
# 4          272.88           1022  ...             1014             46
# ..            ...            ...  ...              ...            ...
# 75         282.66           1014  ...             1006             41
# 76         280.89           1015  ...             1006             46
# 77         279.15           1018  ...             1009             57
# 78         278.08           1020  ...             1012             65
# 79         276.18           1023  ...             1014             63
#
#     clouds.all  wind.speed  wind.deg  wind.gust  sys.pod rain.3h    zip  \
# 0           86        0.71       253       0.88        n     NaN  03301
# 1           61        1.58       269       4.31        n     NaN  03301
# 2            7        4.50       305       7.40        d     NaN  03301
# 3           38        4.16       304       6.51        d     NaN  03301
# 4           99        2.83       320       6.01        d     NaN  03301
# ..         ...         ...       ...        ...      ...     ...    ...
# 75          86        6.89       238      18.08        d     NaN  03867
# 76           0        6.94       268      18.29        d     NaN  03867
# 77           0        6.47       284      16.76        n     NaN  03867
# 78          18        6.06       292      14.49        n     NaN  03867
# 79          11        5.20       288      13.25        n     NaN  03867
#
#          city
# 0     Concord
# 1     Concord
# 2     Concord
# 3     Concord
# 4     Concord
# ..        ...
# 75  Rochester
# 76  Rochester
# 77  Rochester
# 78  Rochester
# 79  Rochester
#
# [80 rows x 21 columns]

# %% [markdown]
# #### Mean of forecasted temperatures for the next 5 days for each location

# %%
df2.groupby(["city"])["main.temp"].mean()
# Out:
# city
# Concord      275.97725
# Rochester    275.99825
# Name: main.temp, dtype: float64

# %% [markdown]
# #### Variance of the forecasted temperature over the next 5 days by location

# %%
df2.groupby(["city"])["main.temp"].var()
# Out:
# city
# Concord      19.418636
# Rochester    22.176369
# Name: main.temp, dtype: float64

# %%
df2["conditions"] = df2["weather"].apply(lambda x : x[0]["description"])
df2
# Out:
#             dt                                            weather  visibility  \
# 0   1639040400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 1   1639051200  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 2   1639062000  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 3   1639072800  [{'id': 802, 'main': 'Clouds', 'description': ...       10000
# 4   1639083600  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# ..         ...                                                ...         ...
# 75  1639418400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 76  1639429200  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 77  1639440000  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 78  1639450800  [{'id': 801, 'main': 'Clouds', 'description': ...       10000
# 79  1639461600  [{'id': 801, 'main': 'Clouds', 'description': ...       10000
#
#     pop          Time of Day  main.temp  main.feels_like  main.temp_min  \
# 0   0.0  2021-12-09 09:00:00     269.07           269.07         269.07
# 1   0.0  2021-12-09 12:00:00     269.14           266.68         269.14
# 2   0.0  2021-12-09 15:00:00     273.95           269.53         273.95
# 3   0.0  2021-12-09 18:00:00     275.21           271.30         275.21
# 4   0.0  2021-12-09 21:00:00     272.88           269.48         272.88
# ..  ...                  ...        ...              ...            ...
# 75  0.0  2021-12-13 18:00:00     282.66           279.49         282.66
# 76  0.0  2021-12-13 21:00:00     280.89           277.20         280.89
# 77  0.0  2021-12-14 00:00:00     279.15           275.14         279.15
# 78  0.0  2021-12-14 03:00:00     278.08           273.93         278.08
# 79  0.0  2021-12-14 06:00:00     276.18           271.92         276.18
#
#     main.temp_max  main.pressure  ...  main.humidity  clouds.all  wind.speed  \
# 0          269.50           1014  ...             90          86        0.71
# 1          269.28           1016  ...             92          61        1.58
# 2          273.95           1019  ...             51           7        4.50
# 3          275.21           1020  ...             38          38        4.16
# 4          272.88           1022  ...             46          99        2.83
# ..            ...            ...  ...            ...         ...         ...
# 75         282.66           1014  ...             41          86        6.89
# 76         280.89           1015  ...             46           0        6.94
# 77         279.15           1018  ...             57           0        6.47
# 78         278.08           1020  ...             65          18        6.06
# 79         276.18           1023  ...             63          11        5.20
#
#     wind.deg  wind.gust  sys.pod  rain.3h    zip       city        conditions
# 0        253       0.88        n      NaN  03301    Concord   overcast clouds
# 1        269       4.31        n      NaN  03301    Concord     broken clouds
# 2        305       7.40        d      NaN  03301    Concord         clear sky
# 3        304       6.51        d      NaN  03301    Concord  scattered clouds
# 4        320       6.01        d      NaN  03301    Concord   overcast clouds
# ..       ...        ...      ...      ...    ...        ...               ...
# 75       238      18.08        d      NaN  03867  Rochester   overcast clouds
# 76       268      18.29        d      NaN  03867  Rochester         clear sky
# 77       284      16.76        n      NaN  03867  Rochester         clear sky
# 78       292      14.49        n      NaN  03867  Rochester        few clouds
# 79       288      13.25        n      NaN  03867  Rochester        few clouds
#
# [80 rows x 22 columns]

# %%
df2["conditions"].value_counts()
# Out:
# overcast clouds     43
# clear sky           15
# light rain           8
# few clouds           8
# broken clouds        5
# scattered clouds     1
# Name: conditions, dtype: int64

# %% [markdown]
# #### The mode of the conditions between both locations is the top value in the output in the cell above.

# %%
df2["main.humidity"].median()
# Out:
# 63.0

# %% [markdown]
# #### The median humidity is the output of the cell above which is a percentage.

# %%
df2["main.humidity"].std()
# Out:
# 18.16407289964994

# %% [markdown]
# #### The standard deviation of the humidity between both locations is the output of the cell above

# %%
import matplotlib.pyplot as plt
df2["Time of Day"] = pd.to_datetime(df2["Time of Day"])
df2.to_csv(r"C:\Users\david\Documents\comp574-active\final-project-comp574\final_data.csv", index=False)

# %% [markdown]
# ## Describe at least two more questions that your analysis is meant to answer using graphs. You should include at least two graphs of different kinds (e.g., pie chart, bar chart, histogram, box plots, etc.) to support your answer to these two questions. Explain the purpose of each graph and indicate what particular features are worth pointing out? (25 pts)

# %% [markdown]
# ### Which city has more cloud cover over the course of the next 5 days?

# %%
x = df2["city"][0]
y = df2["city"][40]

# %%
plt.title("Cloud Cover in {}".format(x))
plt.ylabel("% Cloud Cover")
plt.plot(df2["Time of Day"][0:39], df2["clouds.all"][0:39])

# %%
plt.title("Cloud Cover in {}".format(y))
plt.ylabel("% Cloud Cover")
plt.plot(df2["Time of Day"][40:], df2["clouds.all"][40:])

# %% [markdown]
# #### It would appear as though between Concord and Nashua, the cloud cover is forecasted to be greater in Nashua for at least 3 of the next 5 days based on measurements provided at the time of the request was made.

# %% [markdown]
# ### Which city will experience the highestest winds consistantly?

# %%
plt.title("Wind Speeds in {}".format(x))
plt.xlabel("Wind Speed Meters/Second")
plt.ylabel("# of Occurances")
plt.hist(df2["wind.speed"][0:39], bins=20)
# Out:
# (array([2., 5., 4., 2., 1., 0., 5., 3., 1., 1., 1., 4., 2., 0., 2., 2., 1.,
#         1., 0., 2.]),
#  array([0.11  , 0.5175, 0.925 , 1.3325, 1.74  , 2.1475, 2.555 , 2.9625,
#         3.37  , 3.7775, 4.185 , 4.5925, 5.    , 5.4075, 5.815 , 6.2225,
#         6.63  , 7.0375, 7.445 , 7.8525, 8.26  ]),
#  <BarContainer object of 20 artists>)

# %%
plt.title("Wind Speeds in {}".format(y))
plt.xlabel("Wind Speed Meters/Second")
plt.ylabel("# of Occurances")
plt.hist(df2["wind.speed"][40:], bins=20)
# Out:
# (array([3., 7., 3., 1., 0., 2., 2., 1., 2., 2., 3., 4., 1., 1., 1., 3., 1.,
#         1., 1., 1.]),
#  array([0.28 , 0.701, 1.122, 1.543, 1.964, 2.385, 2.806, 3.227, 3.648,
#         4.069, 4.49 , 4.911, 5.332, 5.753, 6.174, 6.595, 7.016, 7.437,
#         7.858, 8.279, 8.7  ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# #### The distributions shown in the two histograms above show that the wind speeds in Concord are going to be consistantly higher than in Nashua. Nashua is supposed to have higher speeds but they should not occur as often as they do in Concord.
