# %%
# 03301 = Zip code for Concord, NH, USA
#30100,IT = Zip code for Venezia, Italy - Part of Venice, Italy 
import requests, json, pandas as pd

api_key = "8390c20af9c3e9f5dcf4f89d947eba14"
base_url = "http://api.openweathermap.org/data/2.5/forecast?"
zips=["03301", "30100,IT"]

# For loop to split up different zips as I want two separate dataframes. Probably not the best way, but functional.
for zip in zips:
    if zip == "03301":
        complete_url = base_url + "zip=" + zip + "&appid=" + api_key
    else:
        complete_url1 = base_url + "zip=" + zip + "&appid=" + api_key

# %%
# creates json payload for the urls made above
payload = requests.get(complete_url).json()
payload1 = requests.get(complete_url1).json()

# %%
# Creates dataframes from the payload --- normalize = json --> dataframe
df = pd.json_normalize(payload["list"]).drop("main.temp_kf", axis= 1)
df1 = pd.json_normalize(payload1["list"]).drop("main.temp_kf", axis= 1)

# %%
# Sends each dataframe to a csv file for the location
# headers will be column names by default
# Index = false is needed so that the datframe indexes do not become Unnamed: 0
df.to_csv(r"C:\Users\david\Documents\comp574-active\final-project-comp574\concord.csv", index=False)
df1.to_csv(r"C:\Users\david\Documents\comp574-active\final-project-comp574\venezia.csv",index=False)
df1.columns
# Out:
# Index(['dt', 'weather', 'visibility', 'pop', 'dt_txt', 'main.temp',
#        'main.feels_like', 'main.temp_min', 'main.temp_max', 'main.pressure',
#        'main.sea_level', 'main.grnd_level', 'main.humidity', 'clouds.all',
#        'wind.speed', 'wind.deg', 'wind.gust', 'sys.pod', 'rain.3h'],
#       dtype='object')

# %%
# Read file to make sure everything works
pd.read_csv(r"C:\Users\david\Documents\comp574-active\final-project-comp574\concord.csv")
# Out:
#             dt                                            weather  visibility  \
# 0   1636092000  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 1   1636102800  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 2   1636113600  [{'id': 802, 'main': 'Clouds', 'description': ...       10000
# 3   1636124400  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 4   1636135200  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 5   1636146000  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 6   1636156800  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 7   1636167600  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 8   1636178400  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 9   1636189200  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 10  1636200000  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 11  1636210800  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 12  1636221600  [{'id': 802, 'main': 'Clouds', 'description': ...       10000
# 13  1636232400  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 14  1636243200  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 15  1636254000  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 16  1636264800  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 17  1636275600  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 18  1636286400  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 19  1636297200  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 20  1636308000  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 21  1636318800  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 22  1636329600  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 23  1636340400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 24  1636351200  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 25  1636362000  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 26  1636372800  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 27  1636383600  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 28  1636394400  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 29  1636405200  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 30  1636416000  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 31  1636426800  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 32  1636437600  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 33  1636448400  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 34  1636459200  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 35  1636470000  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 36  1636480800  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 37  1636491600  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 38  1636502400  [{'id': 802, 'main': 'Clouds', 'description': ...       10000
# 39  1636513200  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
#
#     pop               dt_txt  main.temp  main.feels_like  main.temp_min  \
# 0     0  2021-11-05 06:00:00     274.26           274.26         272.96
# 1     0  2021-11-05 09:00:00     273.64           272.11         272.41
# 2     0  2021-11-05 12:00:00     273.33           271.57         272.86
# 3     0  2021-11-05 15:00:00     280.08           278.24         280.08
# 4     0  2021-11-05 18:00:00     282.08           280.12         282.08
# 5     0  2021-11-05 21:00:00     278.53           277.69         278.53
# 6     0  2021-11-06 00:00:00     273.99           273.99         273.99
# 7     0  2021-11-06 03:00:00     273.08           273.08         273.08
# 8     0  2021-11-06 06:00:00     272.78           272.78         272.78
# 28         286.76           1019            1019             1011
# 29         283.27           1019            1019             1011
# 30         279.31           1022            1022             1013
# 31         278.06           1023            1023             1014
# 32         277.36           1023            1023             1014
# 33         276.84           1023            1023             1014
# 34         276.84           1023            1023             1015
# 35         284.58           1022            1022             1014
# 36         288.57           1019            1019             1011
# 37         285.07           1019            1019             1010
# 38         281.31           1019            1019             1011
# 39         280.26           1019            1019             1010
#
#     main.humidity  clouds.all  wind.speed  wind.deg  wind.gust sys.pod
# 0              86          90        1.15       339       1.07       n
# 1              84          75        1.40       332       1.41       n
# 2              82          48        1.52       325       1.75       d
# 3              45           2        2.63       331       4.14       d
# 4              33           1        3.44       321       4.85       d
# 5              54           2        1.38       324       1.38       d
# 6              66           2        1.04       301       0.99       n
# 7              71           0        1.12       282       1.06       n
# 8              74           1        1.21       288       1.11       n
# 9              77           3        1.02       297       0.99       n
# 10             76           8        0.92       277       0.89       d
# 11             47          56        1.68       275       3.11       d
# 12             36          49        1.83       234       2.98       d
# 13             59           4        1.55       228       1.53       d
# 14             74           2        1.07       224       1.15       n
# 15             83           1        0.78       238       0.87       n
# 16             87           6        0.69       282       0.70       n
# 17             86          64        0.63       263       0.65       n
# 18             79          78        0.67       304       0.66       d
# 19             49         100        0.97       232       1.50       d
# 20             42          91        1.73       192       2.44       d
# 21             64          96        0.95       155       1.04       d
# 22             75          98        0.63       309       0.59       n
# 23             82         100        0.72       332       0.70       n
# 24             81         100        1.75       334       1.70       n
# 25             81         100        1.54       348       1.55       n
# 26             79          74        1.73       337       2.01       d
# 27             51           2        1.84       341       3.02       d
# 28             50           1        1.85       358       3.17       d
# 29             74           0        0.96         6       1.09       d
# 30             90           0        1.50       327       1.41       n
# 31             93           0        1.29       330       1.30       n
# 32             94           0        1.31       325       1.25       n
# 33             94           0        0.97       334       0.94       n
# 34             94           3        0.63       306       0.58       d
# 35             65           7        1.50       201       2.66       d
# 36             52           5        2.39       190       3.91       d
# 37             75           0        1.80       167       1.97       d
# 38             89          34        1.33       211       1.46       n
# 39             92          64        1.28       236       1.25       n

# %%
# Read file to make sure that everything works
pd.read_csv(r"C:\Users\david\Documents\comp574-active\final-project-comp574\venezia.csv")
# Out:
#             dt                                            weather  visibility  \
# 0   1636092000  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 1   1636102800  [{'id': 802, 'main': 'Clouds', 'description': ...       10000
# 2   1636113600  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 3   1636124400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 4   1636135200  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 5   1636146000  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 6   1636156800  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 7   1636167600  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 8   1636178400  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 9   1636189200  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 10  1636200000  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 11  1636210800  [{'id': 802, 'main': 'Clouds', 'description': ...       10000
# 12  1636221600  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 13  1636232400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 14  1636243200  [{'id': 500, 'main': 'Rain', 'description': 'l...       10000
# 15  1636254000  [{'id': 500, 'main': 'Rain', 'description': 'l...       10000
# 16  1636264800  [{'id': 500, 'main': 'Rain', 'description': 'l...       10000
# 17  1636275600  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 18  1636286400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 19  1636297200  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 20  1636308000  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 21  1636318800  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 22  1636329600  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 23  1636340400  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 24  1636351200  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 25  1636362000  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 26  1636372800  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 27  1636383600  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 28  1636394400  [{'id': 804, 'main': 'Clouds', 'description': ...       10000
# 29  1636405200  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 30  1636416000  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 31  1636426800  [{'id': 802, 'main': 'Clouds', 'description': ...       10000
# 32  1636437600  [{'id': 803, 'main': 'Clouds', 'description': ...       10000
# 33  1636448400  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 34  1636459200  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 35  1636470000  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 36  1636480800  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 37  1636491600  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 38  1636502400  [{'id': 800, 'main': 'Clear', 'description': '...       10000
# 39  1636513200  [{'id': 802, 'main': 'Clouds', 'description': ...       10000
# 6          283.57           1024            1024             1023
# 7          282.66           1024            1024             1024
# 8          282.42           1025            1025             1024
# 9          284.61           1026            1026             1026
# 10         287.25           1025            1025             1024
# 11         286.81           1023            1023             1023
# 12         285.05           1024            1024             1023
# 13         284.83           1023            1023             1022
# 14         283.97           1023            1023             1022
# 15         283.05           1022            1022             1021
# 16         283.28           1021            1021             1020
# 17         284.27           1021            1021             1020
# 18         286.51           1019            1019             1018
# 19         286.80           1017            1017             1017
# 20         286.30           1017            1017             1017
# 21         285.98           1017            1017             1016
# 22         285.42           1016            1016             1015
# 23         284.57           1015            1015             1015
# 24         284.34           1015            1015             1015
# 25         286.32           1016            1016             1016
# 26         288.28           1016            1016             1015
# 27         286.60           1016            1016             1016
# 28         285.63           1018            1018             1018
# 29         284.78           1019            1019             1018
# 30         284.50           1020            1020             1019
# 31         283.37           1020            1020             1020
# 32         282.95           1022            1022             1022
# 33         285.02           1024            1024             1023
# 34         287.20           1024            1024             1023
# 35         286.62           1024            1024             1023
# 36         284.60           1025            1025             1025
# 37         283.14           1026            1026             1025
# 38         281.98           1025            1025             1025
# 39         281.99           1025            1025             1025
#
#     main.humidity  clouds.all  wind.speed  wind.deg  wind.gust sys.pod  \
# 0              94           0        2.88         6       3.11       d
# 1              83          33        3.74        11       4.56       d
# 2              66          67        2.68        19       3.42       d
# 3              58         100        2.37        29       3.46       d
# 4              68         100        4.68        59       6.34       n
# 5              69         100        6.46        52      10.60       n
# 6              73          95        7.12        41      11.78       n
# 7              68          57        6.73        43      11.05       n
# 8              62          79        6.99        37      12.94       d
# 9              57         100        7.68        49      12.77       d
# 10             52          82        7.95        61      10.06       d
# 11             56          40        5.58        52       7.86       d
# 12             61          63        4.96        44       7.08       n
# 13             64         100        5.54        51       8.20       n
# 14             68         100        3.10        48       4.22       n
# 15             75         100        2.41        33       4.10       n
# 16             74         100        2.49         5       3.29       d
# 17             64          99        2.09       355       2.54       d
# 18             54          90        2.43       316       2.46       d
# 19             56          84        1.00       319       1.16       d
# 20             59          92        1.86       304       1.97       n
# 21             62         100        2.30       285       2.47       n
# 22             62          80        0.23       266       0.36       n
# 23             67          70        2.02       305       2.00       n
# 24             67          79        0.52       318       0.88       d
# 25             64          75        0.96         9       1.05       d
# 26             68          84        3.85        29       4.43       d
# 27             71          82        6.71        53       9.36       d
# 28             70          91        6.83        63      10.06       n
# 29             71          73        6.55        55      11.13       n
# 30             70          56        7.60        55      12.90       n
# 31             75          38        6.02        47      10.64       n
# 32             71          57        7.04        44      11.42       n
# 33             65           4        8.26        53      12.69       d
# 34             53           2        8.35        51      11.00       d
# 35             57           2        6.83        57       9.17       d
# 36             64           2        6.94        67       9.59       n
# 37             69           0        6.02        55       9.35       n
# 38             69           2        4.64        46       6.80       n
# 39             69          48        4.15        23       5.36       n
#
#     rain.3h
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14     0.20
# 15     1.24
# 16     0.52
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
# 30      NaN
# 31      NaN
# 32      NaN
# 33      NaN
# 34      NaN
# 35      NaN
# 36      NaN
# 37      NaN
# 38      NaN
# 39      NaN
